# %%
from typing import TypedDict
from langgraph.graph import StateGraph

# %%
class Son(TypedDict):
    name: str
    years: int
    MSSV: str
son_real : Son = {
    'name': 'Son',
    'years': 20,
    'MSSV' : 'ngu'
}
print(son_real['MSSV'])
# Out:
# ngu

# %%
StateGraph = {
    'name': None,

}
print(type(StateGraph))
# Out:
# <class 'dict'>

# %%
class StateGraph(TypedDict):
    name: str
son_real : StateGraph = {
    'name': 'son'
}
print(type(son_real))
# Out:
# <class 'dict'>

# %%
res = app.invoke({'name' : 'Son'})
print(res['name'])
# Out:
# Hello Son

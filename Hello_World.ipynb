# %%
from typing import Dict, TypedDict
from langgraph.graph import StateGraph

# %%
data: Dict[str, int] = {"age" : 20}
print(data)
# Out:
# {'age': 20}

# %%
class AgentState(TypedDict):
    message : str
    year : int

def greeting_node(state: AgentState) -> AgentState:
    """Simple node that adds a greeting message to the state"""

    state['message'] = "Hey " + state['message'] + ", how is your day going?"
    
    return state
def majority_node(state: AgentState) -> AgentState:
    x = int(input("Year of university ?"))
    state['year'] = x
    return state

# %%
graph = StateGraph(AgentState)

graph.add_node("greeter", greeting_node)
graph.add_node("major", majority_node)
graph.set_entry_point("greeter")
graph.set_finish_point("greeter")

graph.add_edge("greeter", "major")
app = graph.compile()

# %%
res = app.invoke({'message': 'Son', 'year' : 0})
print(res['message'])
print(res['year'])
# Out:
# Hey Son, how is your day going?
# 3
